# %%
"""
# 7️⃣ Regularization
Technique	Effect	Code
L2 (Weight Decay)	Penalises large weights	Add lambda * np.sum(W**2) to loss, subtract lambda * W during update
Dropout	Randomly zeroes activations during training	mask = (np.random.rand(*a.shape) > p).astype(float)
Early‑stopping	Stop when validation loss plateaus	Keep best weights, monitor val loss
"""
# Simple L2 in loss

lambda_reg = 0.01
loss += lambda_reg * (np.sum(mlp.W1**2) + np.sum(mlp.W2**2))

# Update rule subtract lambda_reg * W

mlp.W1 -= lr * (dW1 + lambda_reg * mlp.W1)
